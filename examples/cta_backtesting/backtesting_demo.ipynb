# %%
#%%
from vnpy.app.cta_strategy.backtesting import BacktestingEngine, OptimizationSetting
from vnpy.app.cta_strategy.strategies.atr_rsi_strategy import (
    AtrRsiStrategy,
)
from datetime import datetime

# %%
#%%
engine = BacktestingEngine()
engine.set_parameters(
    vt_symbol="IF888.CFFEX",
    interval="1m",
    start=datetime(2019, 1, 1),
    end=datetime(2019, 4, 30),
    rate=0.3/10000,
    slippage=0.2,
    size=300,
    pricetick=0.2,
    capital=1_000_000,
)
engine.add_strategy(AtrRsiStrategy, {})

# %%
#%%
engine.load_data()
engine.run_backtesting()
df = engine.calculate_result()
engine.calculate_statistics()
engine.show_chart()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-06c0f59cbee0> in <module>
#       1 #%%
# ----> 2 engine.load_data()
#       3 engine.run_backtesting()
#       4 df = engine.calculate_result()
#       5 engine.calculate_statistics()
#
# NameError: name 'engine' is not defined

# %%
setting = OptimizationSetting()
setting.set_target("sharpe_ratio")
setting.add_parameter("atr_length", 25, 27, 1)
setting.add_parameter("atr_ma_length", 10, 30, 10)

engine.run_optimization(setting)
# Out:
# 2021-05-12 11:25:23.268914	参数：{'atr_length': 27, 'atr_ma_length': 20}, 目标：2.2129510688136507
# 2021-05-12 11:25:23.269464	参数：{'atr_length': 26, 'atr_ma_length': 20}, 目标：2.053277768106694
# 2021-05-12 11:25:23.269464	参数：{'atr_length': 25, 'atr_ma_length': 20}, 目标：2.00255172692691
# 2021-05-12 11:25:23.269992	参数：{'atr_length': 25, 'atr_ma_length': 30}, 目标：1.4184736461902947
# 2021-05-12 11:25:23.269992	参数：{'atr_length': 26, 'atr_ma_length': 30}, 目标：1.3853715170900258
# 2021-05-12 11:25:23.269992	参数：{'atr_length': 27, 'atr_ma_length': 30}, 目标：1.3558958599285544
# 2021-05-12 11:25:23.269992	参数：{'atr_length': 26, 'atr_ma_length': 10}, 目标：0.9902389498659604
# 2021-05-12 11:25:23.269992	参数：{'atr_length': 27, 'atr_ma_length': 10}, 目标：0.9615278589050578
# 2021-05-12 11:25:23.269992	参数：{'atr_length': 25, 'atr_ma_length': 10}, 目标：0.9243923627051885
# [("{'atr_length': 27, 'atr_ma_length': 20}",
#   2.2129510688136507,
#   {'start_date': datetime.date(2019, 1, 15),
#    'end_date': datetime.date(2019, 4, 29),
#    'total_days': 69,
#    'profit_days': 34,
#    'loss_days': 35,
#    'capital': 1000000,
#    'end_balance': 1191705.5422,
#    'max_drawdown': -76786.91940000025,
#    'max_ddpercent': -6.80057756062981,
#    'max_drawdown_duration': 14,
#    'total_net_pnl': 191705.54219999988,
#    'daily_net_pnl': 2778.341191304346,
#    'total_commission': 10434.457799999996,
#    'daily_commission': 151.22402608695648,
#    'total_slippage': 20700.0,
#    'daily_slippage': 300.0,
#    'total_turnover': 347815260.0,
#    'daily_turnover': 5040800.869565218,
#    'total_trade_count': 345,
#    'daily_trade_count': 5.0,
#    'total_return': 19.170554220000003,
#    'annual_return': 66.68018859130436,
#    'daily_return': 0.2293015805903696,
#    'return_std': 1.6052432706731907,
#    'sharpe_ratio': 2.2129510688136507,
#    'return_drawdown_ratio': 2.818959720565939}),
#  ("{'atr_length': 26, 'atr_ma_length': 20}",
#   2.053277768106694,
#   {'start_date': datetime.date(2019, 1, 15),
#    'end_date': datetime.date(2019, 4, 29),
#    'total_days': 69,
#    'profit_days': 33,
#    'loss_days': 36,
#    'capital': 1000000,
#    'end_balance': 1178327.0488,
#    'max_drawdown': -93267.37020000024,
#    'max_ddpercent': -8.260156676126181,
#    'max_drawdown_duration': 31,
#    'total_net_pnl': 178327.0487999998,
#    'daily_net_pnl': 2584.4499826086926,
#    'total_commission': 10432.951199999998,
#    'daily_commission': 151.2021913043478,
#    'total_slippage': 20700.0,
#    'daily_slippage': 300.0,
#    'total_turnover': 347765040.0,
#    'daily_turnover': 5040073.043478261,
#    'total_trade_count': 345,
#    'daily_trade_count': 5.0,
#    'total_return': 17.832704879999994,
#    'annual_return': 62.026799582608675,
#    'daily_return': 0.21293950448386414,
#    'return_std': 1.6066236481508744,
#    'sharpe_ratio': 2.053277768106694,
#    'return_drawdown_ratio': 2.1588821591654255}),
#  ("{'atr_length': 25, 'atr_ma_length': 20}",
#   2.00255172692691,
#   {'start_date': datetime.date(2019, 1, 15),
#    'end_date': datetime.date(2019, 4, 29),
#    'total_days': 69,
#    'profit_days': 33,
#    'loss_days': 36,
#    'capital': 1000000,
#    'end_balance': 1173885.9039999999,
#    'max_drawdown': -92459.28960000037,
#    'max_ddpercent': -8.22113013563611,
#    'max_drawdown_duration': 31,
#    'total_net_pnl': 173885.9039999999,
#    'daily_net_pnl': 2520.0855652173896,
#    'total_commission': 10434.095999999998,
#    'daily_commission': 151.21878260869562,
#    'total_slippage': 20700.0,
#    'daily_slippage': 300.0,
#    'total_turnover': 347803200.0,
#    'daily_turnover': 5040626.0869565215,
#    'total_trade_count': 345,
#    'daily_trade_count': 5.0,
#    'total_return': 17.38859039999998,
#    'annual_return': 60.48205356521733,
#    'daily_return': 0.20746682873848182,
#    'return_std': 1.6049834055026801,
#    'sharpe_ratio': 2.00255172692691,
#    'return_drawdown_ratio': 2.1151094938426658}),
#  ("{'atr_length': 25, 'atr_ma_length': 30}",
#   1.4184736461902947,
#   {'start_date': datetime.date(2019, 1, 15),
#    'end_date': datetime.date(2019, 4, 29),
#    'total_days': 69,
#    'profit_days': 32,
#    'loss_days': 37,
#    'capital': 1000000,
#    'end_balance': 1126432.4716,
#    'max_drawdown': -76562.41199999978,
#    'max_ddpercent': -6.364317341972757,
#    'max_drawdown_duration': 10,
#    'total_net_pnl': 126432.47159999992,
#    'daily_net_pnl': 1832.354660869564,
#    'total_commission': 10367.528399999997,
#    'daily_commission': 150.25403478260867,
#    'total_slippage': 20580.0,
#    'daily_slippage': 298.2608695652174,
#    'total_turnover': 345584280.0,
#    'daily_turnover': 5008467.826086956,
#    'total_trade_count': 343,
#    'daily_trade_count': 4.971014492753623,
#    'total_return': 12.643247160000005,
#    'annual_return': 43.976511860869586,
#    'daily_return': 0.14800589059159533,
#    'return_std': 1.6164539988216182,
#    'sharpe_ratio': 1.4184736461902947,
#    'return_drawdown_ratio': 1.9865833962454422}),
#  ("{'atr_length': 26, 'atr_ma_length': 30}",
#   1.3853715170900258,
#   {'start_date': datetime.date(2019, 1, 15),
#    'end_date': datetime.date(2019, 4, 29),
#    'total_days': 69,
#    'profit_days': 32,
#    'loss_days': 37,
#    'capital': 1000000,
#    'end_balance': 1123731.5956,
#    'max_drawdown': -76562.41200000001,
#    'max_ddpercent': -6.3786381932446155,
#    'max_drawdown_duration': 10,
#    'total_net_pnl': 123731.5955999999,
#    'daily_net_pnl': 1793.2115304347813,
#    'total_commission': 10428.404399999998,
#    'daily_commission': 151.13629565217389,
#    'total_slippage': 20700.0,
#    'daily_slippage': 300.0,
#    'total_turnover': 347613480.0,
#    'daily_turnover': 5037876.521739131,
#    'total_trade_count': 345,
#    'daily_trade_count': 5.0,
#    'total_return': 12.37315955999998,
#    'annual_return': 43.03707673043471,
#    'daily_return': 0.14452675324303127,
#    'return_std': 1.6161721285202792,
#    'sharpe_ratio': 1.3853715170900258,
#    'return_drawdown_ratio': 1.9397807471042872}),
#  ("{'atr_length': 27, 'atr_ma_length': 30}",
#   1.3558958599285544,
#   {'start_date': datetime.date(2019, 1, 15),
#    'end_date': datetime.date(2019, 4, 29),
#    'total_days': 69,
#    'profit_days': 31,
#    'loss_days': 38,
#    'capital': 1000000,
#    'end_balance': 1120785.949,
#    'max_drawdown': -77822.44980000006,
#    'max_ddpercent': -6.492733563181508,
#    'max_drawdown_duration': 10,
#    'total_net_pnl': 120785.9490000001,
#    'daily_net_pnl': 1750.5210000000013,
#    'total_commission': 10434.050999999996,
#    'daily_commission': 151.21813043478255,
#    'total_slippage': 20700.0,
#    'daily_slippage': 300.0,
#    'total_turnover': 347801700.0,
#    'daily_turnover': 5040604.347826087,
#    'total_trade_count': 345,
#    'daily_trade_count': 5.0,
#    'total_return': 12.078594900000006,
#    'annual_return': 42.01250400000002,
#    'daily_return': 0.14072276828007052,
#    'return_std': 1.6078430625479947,
#    'sharpe_ratio': 1.3558958599285544,
#    'return_drawdown_ratio': 1.8603250514535772}),
#  ("{'atr_length': 26, 'atr_ma_length': 10}",
#   0.9902389498659604,
#   {'start_date': datetime.date(2019, 1, 15),
#    'end_date': datetime.date(2019, 4, 29),
#    'total_days': 69,
#    'profit_days': 31,
#    'loss_days': 38,
#    'capital': 1000000,
#    'end_balance': 1095952.3732,
#    'max_drawdown': -139507.3776,
#    'max_ddpercent': -12.153636211744773,
#    'max_drawdown_duration': 31,
#    'total_net_pnl': 95952.37320000006,
#    'daily_net_pnl': 1390.614104347827,
#    'total_commission': 11327.626799999998,
#    'daily_commission': 164.16850434782606,
#    'total_slippage': 22380.0,
#    'daily_slippage': 324.3478260869565,
#    'total_turnover': 377587560.0,
#    'daily_turnover': 5472283.478260869,
#    'total_trade_count': 373,
#    'daily_trade_count': 5.405797101449275,
#    'total_return': 9.595237320000006,
#    'annual_return': 33.374738504347846,
#    'daily_return': 0.10833515851897027,
#    'return_std': 1.6948647184985288,
#    'sharpe_ratio': 0.9902389498659604,
#    'return_drawdown_ratio': 0.7894951891622002}),
#  ("{'atr_length': 27, 'atr_ma_length': 10}",
#   0.9615278589050578,
#   {'start_date': datetime.date(2019, 1, 15),
#    'end_date': datetime.date(2019, 4, 29),
#    'total_days': 69,
#    'profit_days': 31,
#    'loss_days': 38,
#    'capital': 1000000,
#    'end_balance': 1093672.4416,
#    'max_drawdown': -139507.3776,
#    'max_ddpercent': -12.153636211744773,
#    'max_drawdown_duration': 31,
#    'total_net_pnl': 93672.44160000008,
#    'daily_net_pnl': 1357.5716173913054,
#    'total_commission': 11327.558399999998,
#    'daily_commission': 164.16751304347824,
#    'total_slippage': 22380.0,
#    'daily_slippage': 324.3478260869565,
#    'total_turnover': 377585280.0,
#    'daily_turnover': 5472250.434782608,
#    'total_trade_count': 373,
#    'daily_trade_count': 5.405797101449275,
#    'total_return': 9.36724416000001,
#    'annual_return': 32.58171881739134,
#    'daily_return': 0.1053170616583024,
#    'return_std': 1.6968462103161195,
#    'sharpe_ratio': 0.9615278589050578,
#    'return_drawdown_ratio': 0.77073593423406}),
#  ("{'atr_length': 25, 'atr_ma_length': 10}",
#   0.9243923627051885,
#   {'start_date': datetime.date(2019, 1, 15),
#    'end_date': datetime.date(2019, 4, 29),
#    'total_days': 69,
#    'profit_days': 31,
#    'loss_days': 38,
#    'capital': 1000000,
#    'end_balance': 1090790.8726000001,
#    'max_drawdown': -146468.93219999992,
#    'max_ddpercent': -12.760114546669746,
#    'max_drawdown_duration': 31,
#    'total_net_pnl': 90790.87260000008,
#    'daily_net_pnl': 1315.8097478260881,
#    'total_commission': 11389.127399999998,
#    'daily_commission': 165.0598173913043,
#    'total_slippage': 22500.0,
#    'daily_slippage': 326.0869565217391,
#    'total_turnover': 379637580.0,
#    'daily_turnover': 5501993.9130434785,
#    'total_trade_count': 375,
#    'daily_trade_count': 5.434782608695652,
#    'total_return': 9.07908726000002,
#    'annual_return': 31.579433947826153,
#    'daily_return': 0.10149352353644656,
#    'return_std': 1.700934547984498,
#    'sharpe_ratio': 0.9243923627051885,
#    'return_drawdown_ratio': 0.7115208274027262})]
