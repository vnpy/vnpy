# %% [markdown]
# # 准备数据

# %%
# 加载模块
import polars as pl

from vnpy.trader.constant import Interval

from vnpy.alpha import AlphaLab

# %%
# 创建数据中心
lab: AlphaLab = AlphaLab("./lab/csi300")

# %%
# 设置任务参数
name = "101"
index_symbol: str = "000300.SSE"
start: str = "2008-01-01"
end: str = "2023-12-31"
interval: Interval = Interval.DAILY
extended_days: int = 100

# %%
# 加载所有成分股代码
component_symbols: list[str] = lab.load_component_symbols(index_symbol, start, end)

# %% [markdown]
# # 特征计算

# %%
# 加载模块
from vnpy.trader.constant import Interval

from vnpy.alpha.dataset import AlphaDataset
from vnpy.alpha.dataset.datasets.alpha_101 import Alpha101

# %%
# 加载成分股数据
df: pl.DataFrame = lab.load_bar_df(component_symbols, interval, start, end, extended_days)

# %%
# 创建数据集对象
dataset: AlphaDataset = Alpha101(
    df,
    train_period = ("2008-01-01", "2014-12-31"),
    valid_period = ("2015-01-01", "2016-12-31"),
    test_period = ("2017-01-01", "2020-8-31"),
)

# %%
# 收集指数成分过滤器
filters: dict[str, list[str]] = lab.load_component_filters(index_symbol, start, end)

# %%
# 准备特征和标签数据
dataset.prepare_data(filters)
# Out:
# 2025-06-26 14:50:48 开始计算表达式因子特征
#   0%|          | 0/2 [00:02<?, ?it/s]
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "c:\veighna_studi\Lib\multiprocessing\pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "C:\Users\dell\Documents\GitHub\vnpy\vnpy\alpha\dataset\template.py", line 274, in calculate_feature
#     result = calculate_by_expression(df, expression)["data"].alias(name)
#              ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^
#   File "C:\Users\dell\Documents\GitHub\vnpy\vnpy\alpha\dataset\utility.py", line 139, in calculate_by_expression
#     for column in df.columns:
#                   ^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'columns'
# """
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 2
#       1 # 准备特征和标签数据
# ----> 2 dataset.prepare_data(filters)
#
# File ~\Documents\GitHub\vnpy\vnpy\alpha\dataset\template.py:115, in AlphaDataset.prepare_data(self, filters, max_workers)
#     112     it = pool.imap(calculate_feature, args)
#     114     # Collect results
# --> 115     for result in tqdm(it, total=len(args)):
#     116         results.append(result)
#     118 self.result_df = self.df.with_columns(results)
#
# File c:\veighna_studi\Lib\site-packages\tqdm\std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File c:\veighna_studi\Lib\multiprocessing\pool.py:873, in IMapIterator.next(self, timeout)
#     871 if success:
#     872     return value
# --> 873 raise value
#
# AttributeError: 'NoneType' object has no attribute 'columns'

# %%
# 特征表现分析
dataset.show_feature_performance("alpha54")
# Out:
# notebook controller is DISPOSED.
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。
# notebook controller is DISPOSED.
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。
